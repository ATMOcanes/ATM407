# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/QG_omega_adia_SUSsummer_composite.png?raw=true" alt="Thermal wind exercise image" style="height: 200px;"></div>
#
#
# # QG omega in summer heavy rains over a SE USA box
# # 2014-07-18 BARELY STARTED - ONLY Z KINKS AND A FEW SOUNDINGS SO FAR
# # analyst Brian Mapes
#
# <h3>University of Miami ATM407, fall 2019</h3>
#
# #### Total omega, and individual QG omega terms, from a 39-year study of each summer's rainiest day in a 10x10 degree box over the southeast USA (based on ERA-Interim data). All data from [Nie and Fan 2019](https://journals.ametsoc.org/doi/full/10.1175/JCLI-D-19-0188.1)
#
#
# * IDV capture commands thanks to `pip install ipyidv`
#
#
# ### Activities
# 1. <a href="#Rain_vapor_cloud">Basic rain, vapor, clouds, Z300</a>
# 1. <a href="#QGO_adia">QGO_adia: Adiabatically forced ascent (where cooling is demanded by inertia, to maintain thermal wind balance)</a>
# 1. <a href="#QGO_PVA">The PVA component of QGO_adia, and its forcing term ($-V.\nabla \zeta_a$, noticing that $\partial / \partial t()$ of it is the forcing)</a>
# 1. <a href="#QGO_WA">The WAA component of QGO_adia, and its forcing term ($-V.\nabla T$)</a>
# 1. <a href="#FinalStory">With displays optimized, tell the story: which term made this day the rainiest day of its summer?</a>
# 1. <a href="#Worldview">Satellite image at NASA Worldview</a>
# 1. <a href="#Forecasts">Was it well forecast and warned? How did NWS observe it?</a>
# 1. <a href="#Newspaper">Was it well reported in newspapers of the region?</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# ### Background: Nie and Fan 2019
#
# [Nie and Fan](https://journals.ametsoc.org/doi/full/10.1175/JCLI-D-19-0188.1) describe their inversion of Quasi-Geostrophic omega equation from ERA Interim data. These are their results, stored at a [Miami data server](https://weather.rsmas.miami.edu/repository/entry/show?entryid=1f1f6f3f-d1e2-45b4-ad25-d4f6b8873b4a).
#
# <hr style="height:2px;">

# %%
# %reload_ext ipyidv
# Out:
# netCDF4 is not installed

# %%
# %make_image -capture legend -caption "Interesting kink in Z300"

# %%
# %make_image -display consounding -caption "Absolutely unstable layer at 300 mb"

# %%
# %make_image -display sounding -caption "Absolutely unstable layer at 300 mb"

# %% [markdown]
# <hr style="height:2px;">
# <a name="Rain_vapor_cloud"></a>
# # Basic rain, vapor, cloud, Z300
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%make_movie -capture legend -caption 'My Case: Multiproduct mean rain, 2 daily means'

# %%
#%make_image -capture legend -caption 'My Case: Column water vapor at 12Z on record rain day'

# %%
#%make_movie -capture legend -caption 'My Case: IR satellite loop and Z300'

# %% [markdown]
# <hr style="height:2px;">
# <a name="QGO_adia"></a>
# # QG omega due to adiabatic forcing (both terms)
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%make_image -capture legend -caption 'My Case: adiabatic omega upward at 500 hPa, section cuts through it'

# %% [markdown]
# # Compare to mean case:

# %%
# %make_image -capture legend -caption 'Adiabatically driven QG term is quite tilted in Mean Case'

# %% [markdown]
# # Back to the present case:

# %%
#%make_image -capture legend -caption 'QG_adia term in my case: strong at midlevels, downward at ground'

# %% [markdown]
# <hr style="height:2px;">
# <a name="QGO_PVA"></a>
# # The PVA part of adiabatic QG omega
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%make_image -capture legend -caption 'QGO_PVA in my case: weak, except at upper levels to NW'

# %%
#%make_image -capture legend -caption 'PVA in my case: vertical gradient active in a couple main areas'

# %% [markdown]
# <hr style="height:2px;">
# <a name="QGO_WA"></a>
# # QG omega due to warm advection (and its forcing term)
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%make_image -capture legend -caption 'QG_WA in my case: Warm Advection the main culprit! Upper level lift to NW'

# %% [markdown]
# ## Much stronger than Mean Case warm advection:

# %%
#%make_image -capture legend -caption 'Mean Case WA term: weaker, but has that upper tail to NW'

# %%
#%make_image -capture legend -caption 'Warm advection (the forcing term): yes positive over N. La.'

# %%
#%make_image -capture legend -caption 'warm advection by SWly winds at 700 hPa, around a closed low there'

# %%
#%make_image -capture legend -caption 'Moved section. YES it ia all about WAA at 700 due to closed low'

# %%
#%make_image -capture legend -caption 'In contrast, lifting due to PVA term is only at upper levels far to NW'

# %% [markdown]
# <hr style="height:2px;">
# <a name="FinalStory"></a>
# # Final story, with displays optimized:
# ### A small 700 hPa cyclone squeezed through between the Highs, moving from SW to NE
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
#%make_movie -capture legend -caption 'Why rainiest day of the year? It was a 700 hPa cyclone moving to the NE'

# %% [markdown]
# <hr style="height:2px;">
# <a name="Worldview"></a>
# # NASA Worldview
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# # My case is [here](http://www.cnn.com)

# %% [markdown]
# # How to import an image file
# `![Text_for_link](imagename.png "Title")`

# %% [markdown]
# <hr style="height:2px;">
# <a name="Forecasts"></a>
# # NWS forecasts and then observations
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# # Resources for forecast and observation archives
# * [CSU_Schumacher_page](http://schumacher.atmos.colostate.edu/resources/archivewx.php)
#
# * [NWS-SPC_since_2003](https://www.spc.noaa.gov/archive/)
#
# * [NWS-WPC_archives](https://www.wpc.ncep.noaa.gov/archives/web_pages/wpc_arch/get_wpc_archives.php)
#
# * [NWS_text_products](https://mesonet.agron.iastate.edu/wx/afos/list.phtml)
#
# * [NWS_past_weather_page](https://www.weather.gov/help-past-weather)
#
# * [GoogleGroup_State_Forecast_Discussion_search](https://groups.google.com/forum/#!search/STATE$20FORECAST$20DISCUSSION)
#
# * [PSU_maproom_huge_link_list_textsearch_for_archive](http://www.meteo.psu.edu/~j2n/natlwx.htm#forecast)
#
# * [Sean_Milrad_EmbryRiddle_link_list_archive_section_is_near_bottom](http://www.shawnmilrad.com/forecast)
#
# *

# %% [markdown]
# ## Was it well forecast? Results and images and discussion:

# %% [markdown]
# <hr style="height:2px;">
# <a name="Newspaper"></a>
# # News or journalism links: use `[text](`
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# ## Search for journalism about the event in the region

# %%
# !ls ../images/*png
# Out:
# 2018-05-04-00Z-cloudpic-RSMAS.jpg
# EnergyMassPlot_spaghettiplot.png
# LMT_1.5_MERRA.png
# LMT_3.2.png
# LMT_5.4.png
# LMT_medium_coverimage.png
# Lab2_geostrophic_ageo.png
# Philippe_NAM_80km_3day.vortlesson.png
# QG_omega_adia_SUSsummer_composite.png
# QG_omega_themal_chinasummer_composite.png
# QGlesson.png
# Thermalwind.png
# purediv.png

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# !date
# Out:
# Thu Nov  7 13:45:30 EST 2019
