# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
#     <div style="float:right; width:150 px"><img src="https://github.com/ATMOcanes/ATM407/blob/master/images/QG_omega_adia_SUSsummer_composite.png?raw=true" alt="Thermal wind exercise image" style="height: 200px;"></div>
#
#
# # QG omega in summer heavy rains over a SE USA box
# # 2017-06-05
# # analyst Ali Walker, guest IDV work by Brian Mapes
#
# <h3>University of Miami ATM407, fall 2019</h3>
#
# #### Total omega, and individual QG omega terms, from a 39-year study of each summer's rainiest day in a 10x10 degree box over the southeast USA (based on ERA-Interim data). All data from [Nie and Fan 2019](https://journals.ametsoc.org/doi/full/10.1175/JCLI-D-19-0188.1)
#
#
# * IDV capture commands thanks to `pip install ipyidv`
#
#
# ### Activities
# 1. <a href="#Rain_vapor_cloud">Basic rain, vapor, clouds, Z300</a>
# 1. <a href="#QGO_adia">QGO_adia: Adiabatically forced ascent (where cooling is demanded by inertia, to maintain thermal wind balance)</a>
# 1. <a href="#QGO_PVA">The PVA component of QGO_adia, and its forcing term ($-V.\nabla \zeta_a$, noticing that $\partial / \partial t()$ of it is the forcing)</a>
# 1. <a href="#QGO_WA">The WAA component of QGO_adia, and its forcing term ($-V.\nabla T$)</a>
# 1. <a href="#FinalStory">With displays optimized, tell the story: which term made this day the rainiest day of its summer?</a>
#
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# ### Background: Nie and Fan 2019
#
# [Nie and Fan](https://journals.ametsoc.org/doi/full/10.1175/JCLI-D-19-0188.1) describe their inversion of Quasi-Geostrophic omega equation from ERA Interim data. These are their results, stored at a [Miami data server](https://weather.rsmas.miami.edu/repository/entry/show?entryid=1f1f6f3f-d1e2-45b4-ad25-d4f6b8873b4a).
#
# <hr style="height:2px;">

# %%
# %reload_ext ipyidv
# Out:
# netCDF4 is not installed

# %% [markdown]
# <hr style="height:2px;">
# <a name="Rain_vapor_cloud"></a>
# # Basic rain, vapor, cloud, Z300
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %make_movie -capture legend -caption '2017-06-05: Multiproduct mean rain, Z300'

# %% [markdown]
# <hr style="height:2px;">
# <a name="QGO_adia"></a>
# # QG omega due to adiabatic forcing (both terms)
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %make_image -capture legend -caption 'Adiabatic lifting ahead of the trof'

# %%
#%make_image -capture legend -caption 'Adiabatically driven QG term is tilted in Mean Case'

# %%
# %make_image -capture legend -caption 'Upper adiabatic lifting near trof, low-level adiabatic lift out ahead'

# %% [markdown]
# <hr style="height:2px;">
# <a name="QGO_PVA"></a>
# # PVA part of QG omega, and its forcing term
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %make_image -capture legend -caption 'PVA responsible for both lobes of QGO_adia'

# %%
# %make_image -capture legend -caption 'Vorticity advection is well about the 300mb level (black line)'

# %% [markdown]
# <hr style="height:2px;">
# <a name="QGO_WA"></a>
# # QG omega due to warm advection (and its forcing term)
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# ### Mean Case warm advection for comparison:

# %%
# %make_image -capture legend -caption 'QG_WA: broad ahead of trof, multilayered'

# %%
# %make_image -capture legend -caption 'Warm advection (the forcing term) similar to QGO_WA, ignoring the super high altitde red blob'

# %%
# %make_image -capture legend -caption 'QGO_dia (diabatic heating) where the rain is. Note unstable sounding'

# %% [markdown]
# <hr style="height:2px;">
# <a name="FinalStory"></a>
# # Final story, with displays optimized:
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %make_movie -capture legend -caption 'Why rainiest day of year? Upper trough destabilized, convection popped up, 2 rounds in that probe corner of the box'

# %% [markdown]
# ## PVA, WA and diabatic terms combine forces to bring negative omega throughout the column above the box --> rain rain rain!

# %% [markdown]
# <hr style="height:2px;">
# <a name="Worldview"></a>
# # Daily timescale rainfall:
#
# ### NASA Worldview (near 18Z) image, with swipe-over of daily IMERG rain
#
# #### Worldview of 2017-06-05 is [here](https://go.nasa.gov/32MgSPn)
#
# #### 12Z-12Z daily totals spanning this 00Z-00Z day are in inches [here](http://www2.mmm.ucar.edu/imagearchive1/surface/precip_rap/20170606/us_precip_20170606.gif) and [here](http://www2.mmm.ucar.edu/imagearchive1/surface/precip_rap/20170607/us_precip_20170607.gif), or in mm [here](http://www2.mmm.ucar.edu/imagearchive1/surface/precip_emc/20170607/precip_st4_20170607.gif)
#
#
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <hr style="height:2px;">
# <a name="Forecasts"></a>
#
# # NWS forecasts, warnings, observations
#
# ## Multi-day outlooks from [SPC archive](https://www.spc.noaa.gov/archive/)
#
# https://www.spc.noaa.gov/products/outlook/archive/2019/day1otlk_v_20190604_2000.gif
#
# https://www.spc.noaa.gov/products/md/2017/md0954.html
# * Nonzero severe storm risk in south florida
#
# https://www.spc.noaa.gov/products/exper/enhtstm/archive/2017/enh00_20170605_052000_201706050453.gif
#
# * 40% probability of thunderstorms for the entire Gulf region

# %% [markdown]
# ## One-day outlooks from SPC
# ####
#
# [day1otlk_20070706_0100.html](https://www.spc.noaa.gov/products/outlook/archive/2017/day1otlk_20170605_0100.html)
# [day1otlk_20070706_1200.html](https://www.spc.noaa.gov/products/outlook/archive/2017/day1otlk_20170605_1200.html)
# [day1otlk_20070706_1300.html](https://www.spc.noaa.gov/products/outlook/archive/2017/day1otlk_20170605_1300.html)
# [day1otlk_20070706_1630.html](https://www.spc.noaa.gov/products/outlook/archive/2017/day1otlk_20170605_1630.html)
# [day1otlk_20070706_2000.html](https://www.spc.noaa.gov/products/outlook/archive/2017/day1otlk_20170605_2000.html)
#
# * By 2000 they warned in the [day-1 outlook](https://www.spc.noaa.gov/products/outlook/archive/2017/day1otlk_20170605_2000.html):
#
# "...Portions of Florida to the central Gulf Coast...
#    The ongoing Marginal Risk across south Florida is expanded
#    northwestward to the central Gulf Coast to account for the
#    possibility of a few strong to briefly severe storms overnight. **The
#    combination of an eastward-moving shortwave trough currently near
#    the Texas Coast and other minor perturbations in southwesterly flow
#    aloft will likely yield multiple clusters of convection across the
#    central and eastern Gulf overnight.** Low-level winds veering with
#    height, some strengthening of 850mb flow, and thin, but adequate,
#    buoyancy may support **occasional low-level rotation in stronger cores
#    near the coast.** As such, Marginal wind/tornado probabilities are
#    extended northwestward."
#
#
# -----------

# %% [markdown]
# -----------
#
# # Observations and realtime warnings
#
# #### From [the SPC archive (2005-present)](https://www.spc.noaa.gov/exper/ma_archive/), here *EDIT DATES IN URLS* is the  [ Watch/Warning summary with radar](https://www.spc.noaa.gov/exper/ma_archive/action-html5.php?BASICPARAM=rgnlwarn.gif&STARTYEAR=2007&STARTMONTH=07&STARTDAY=06&STARTTIME=00&INC=24), a useless [CAPE display](https://www.spc.noaa.gov/exper/ma_archive/action-html5.php?BASICPARAM=mlcp.gif&STARTYEAR=2007&STARTMONTH=07&STARTDAY=07&STARTTIME=00&INC=24), and [other products](http://www.silly.com/).
#
#
#
# ## Better radar display from NCAR-MMM (some manual site operation required)
# [NCAR-MMM case imagery archive](http://www2.mmm.ucar.edu/imagearchive/), choose `RadarComposites south_missvly`.
#
# [In the later hours of this rainy GMT day, convection seems to be popping up randomly throughout the region] (http://www2.mmm.ucar.edu/imagearchive1/RadarComposites/south_missvly/20170605/south_missvly_201706052230.gif)
# No clear synoptic-scale system appears to be driving this convection.
#
#
# ## Soundings in skew-T format (station map [here](http://weather.uwyo.edu/upperair/sounding.html))
#
# [Lake Charles, LA](http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=GIF%3ASKEWT&YEAR=2017&MONTH=06&FROM=0500&TO=0612&STNM=72240)
#
# [LIX Slidell (New Orleans)](http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=GIF%3ASKEWT&YEAR=2017&MONTH=06&FROM=0500&TO=0612&STNM=72233)
#
# [Shelby County, AL](http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=GIF%3ASKEWT&YEAR=2017&MONTH=06&FROM=0500&TO=0612&STNM=72230)
#
#
# ### I notice that, at the Shelby County station, one of the day's balloons got weighed down by snow near the melting level, as often happens in heavy precipitation situations.
#
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# (https://mesonet.agron.iastate.edu/wx/afos/p.php?pil=AFDBMX&e=201706050501)
#
# Area Forecast Discussion
#
# National Weather Service Birmingham AL
#
# 1201 AM CDT Mon Jun 5 2017
#
# # Local Forecast Discussion in AL describes the rain and low in the area
#
# "Rain will continue to be the story for the first half of the week. A
# cut-off low slides southeastward through the ArkLaTex and a surface
# low develops in the northern Gulf of Mexico by late Monday into
# Tuesday. Throughout the day on Monday, a combination of isentropic
# lift in the warm sector and enhanced lift from PVA and the upper
# level diffluence ahead of the trough will lead to scattered rain and
# thunderstorms. The GFS, EC, and NAM all paint a picture for
# widespread rain/storms, but the CAMs hint more at scattered storms.
# Have increased PoPs to 70% in the afternoon on Monday because I
# expect coverage of the scattered storms to be pretty high, though
# "widespread" may not quite describe it. """

# %% [markdown]
# # Headline from the News Mississippi
#
# [Monday weather rundown 6-5-17: More rain + thunderstorms](https://newsms.fm/monday-weather-rundown-6-5-17-more-rain-thunderstorms/)

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# !date
# Out:
# Thu Nov 14 17:19:34 EST 2019
